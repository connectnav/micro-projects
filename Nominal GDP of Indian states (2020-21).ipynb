# %% [markdown]
# # Statewise Nominal GDP 2020-21 [Bar chart]

# %% [markdown]
# ### Program: Python

# %%
from matplotlib import pyplot as plt

states= ["Maharashtra",
"Tamil Nadu",
"Uttar Pradesh",
"Gujarat",
"Karnataka",
"West Bengal",
"Rajasthan",
"Andhra Pradesh",
"Kerala",
"Telangana",
"Madhya Pradesh",
"Delhi",
"Haryana",
"Bihar",
"Punjab",
"Odisha",
"Assam",
"Chhattisgarh",
"Jharkhand",
"Uttarakhand",
"Jammu and Kashmir",
"Himachal Pradesh",
"Goa",
"Tripura",
"Chandigarh",
"Puducherry",
"Meghalaya",
"Sikkim",
"Nagaland",
"Manipur",
"Arunachal Pradesh",
"Mizoram",
"Andaman and Nicobar Islands"]

gdp= [
 430 
,297 
,240 
,230 
,228 
,181 
,140 
,130 
,130 
,130 
,120 
,110 
,100 
,99 
,71 
,67 
,54 
,46 
,43 
,33 
,23 
,20 
,11 
,7.8 
,5.5 
,5.0 
,4.6 
,4.3 
,4.2 
,4.2 
,3.6 
,3.5 
,1.2  ]

plt.bar(range(len(states)),gdp, color="red")  #plot the bars with states on x-axis and height as per the gdp in red color

plt.title("Nominal GDP of all states in India(2020-21)")

plt.ylabel("Nominal GDP (in Billions of USD)",color='blue')

plt.xlabel("<-States->",color='blue')

plt.xticks(range(len(states)),states, rotation=90) #label x-axis with state names at bar center (Vertically)

plt.rcParams["figure.figsize"]=(12,10) #adjusts the size of plot

plt.show()
